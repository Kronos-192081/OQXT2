# %%
from hawk.keygen import hawkkeygen_unpacked
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from hawk.keygen import hawkkeygen_unpacked
#
# File ~/Documents/SSE-checks/hawk/keygen.py:1
# ----> 1 from poly import adjoint, isinvertible, poly_mul_ntt, poly_add, infnorm, l2norm
#       2 from ntrugen.ntrugen_hawk import ntru_solve
#       3 import ntrugen
#
# ModuleNotFoundError: No module named 'poly'

# %%
lhs
