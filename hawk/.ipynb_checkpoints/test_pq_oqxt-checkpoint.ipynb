# %%
from ntrugen import gen_poly
from ntrugen import ntru_gen, karamul
from fft import fft, ifft, add_fft, mul_fft, adj_fft, div_fft

# %%
f, g, F, G = ntru_gen(64)

# %%
fG = karamul(f, G)
gF = karamul(g, F)
lhs = [fG[i] - gF[i] for i in range(n)]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 fG = karamul(f, G)
#       2 gF = karamul(g, F)
#       3 lhs = [fG[i] - gF[i] for i in range(n)]
#
# NameError: name 'karamul' is not defined
