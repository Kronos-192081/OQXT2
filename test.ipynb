# %%
from hawk.keygen import hawkkeygen_unpacked as hku
from ntrugen import karamul, gen_poly
import numpy as np
from falcon import Falcon
from fft import add, mul
import random

# %%
class PolyMatrix2x2:
    """
    2x2 matrix of polynomials in Z[x]/(x^n + 1)
    Determinant must be 1.
    Singleton: only one instance allowed.
    """

    def __init__(self, a, b, c, d):
        """
        Matrix:
            [ a  b ]`
            [ c  d ]
        Each entry is a polynomial (list of ints).
        """
        self.a = a
        self.b = b
        self.c = c
        self.d = d

    # ---------------------------------------------------------
    # Determinant
    # ---------------------------------------------------------
    def det(self):
        """
        det = a*d - b*c  (mod x^n + 1)
        """
        ad = karamul(self.a, self.d)
        bc = karamul(self.b, self.c)
        return [ad[i] - bc[i] for i in range(len(ad))]

    def _det_is_one(self):
        det = self.det()
        expected = [1] + [0] * (len(det) - 1)
        return det == expected

    # ---------------------------------------------------------
    # Inverse (since det = 1)
    # ---------------------------------------------------------
    def inverse(self):
        """
        Since det = 1:

            M^{-1} =
            [  d  -b ]
            [ -c   a ]
        """
        minus_b = [-x for x in self.b]
        minus_c = [-x for x in self.c]

        return PolyMatrix2x2(self.d, minus_b, minus_c, self.a)

    # ---------------------------------------------------------
    # Matrix multiplication (uses karamul)
    # ---------------------------------------------------------
    def __matmul__(self, other):
        """
        Matrix multiplication using karamul.
        """
        if not isinstance(other, PolyMatrix2x2):
            raise TypeError("Can only multiply with another PolyMatrix2x2")

        a = [karamul(self.a, other.a)[i] + karamul(self.b, other.c)[i]
             for i in range(len(self.a))]

        b = [karamul(self.a, other.b)[i] + karamul(self.b, other.d)[i]
             for i in range(len(self.a))]

        c = [karamul(self.c, other.a)[i] + karamul(self.d, other.c)[i]
             for i in range(len(self.a))]

        d = [karamul(self.c, other.b)[i] + karamul(self.d, other.d)[i]
             for i in range(len(self.a))]

        return PolyMatrix2x2(a, b, c, d)

    # ---------------------------------------------------------
    # Pretty polynomial printer
    # ---------------------------------------------------------
    @staticmethod
    def _poly_to_str(p):
        terms = []
        for i, coef in enumerate(p):
            if coef == 0:
                continue
            if i == 0:
                terms.append(str(coef))
            elif i == 1:
                terms.append(f"{coef}x")
            else:
                terms.append(f"{coef}x^{i}")
        return " + ".join(terms) if terms else "0"

    # ---------------------------------------------------------
    # Representation
    # ---------------------------------------------------------
    def __repr__(self):
        return (
            "[ "
            + self._poly_to_str(self.a) + "    "
            + self._poly_to_str(self.b) + " ]\n"
            "[ "
            + self._poly_to_str(self.c) + "    "
            + self._poly_to_str(self.d) + " ]"
        )

# %%
def rand_poly_2x2_gen():
    n1 = [1] + 255 * [0]
    n2, n3 = gen_poly(256), gen_poly(256)
    temp = karamul(n2, n3)
    temp[0] += 1
    n4 = temp
    return PolyMatrix2x2(n1, n2, n3, n4)

# %%
def random_poly(deg, q):
    """
    Generate a random polynomial in Z_q[x]/(x^deg + 1)
    Represented as a list of coefficients [a0, a1, ..., a_{deg-1}]
    """
    return [random.randint(0, q-1) for _ in range(deg)]

def random_poly_matrix_2x2(deg, q):
    """
    Generate a 2x2 matrix of random polynomials in Z_q[x]/(x^deg + 1)
    """
    return PolyMatrix2x2(random_poly(deg, q), random_poly(deg, q), random_poly(deg, q), random_poly(deg, q))

# %%
def get_infinity_norm(poly):
    """
    Get the infinity norm of a polynomial (max absolute coefficient)
    """
    return max(abs(coef) for coef in poly)

def get_inf_norm_matrix(matrix):
    return get_infinity_norm(matrix.a) + get_infinity_norm(matrix.b) + get_infinity_norm(matrix.c) + get_infinity_norm(matrix.d)

# %%
f, g, F, G = hku(8)[:4]

# %%
B = PolyMatrix2x2(f, g, F, G)

# %%
xw = random_poly_matrix_2x2(256, 1<<32)

# %%
zw = B.__matmul__(PolyMatrix2x2(*(hku(8)[:4])))

# %%
# ## round zw to mod p1
# p1 = 23835 * 1024 + 1
# a = [i%p1 for i in zw.a]
# b = [i%p1 for i in zw.b]
# c = [i%p1 for i in zw.c]
# d = [i%p1 for i in zw.d]
# zw = PolyMatrix2x2(a, b, c, d)

# %%
assert zw._det_is_one() == True

# %%
zw_inv = zw.inverse()

# %% [markdown]
# ### Rounding params
# $$p_1 = (23835 \cdot (2 \cdot 512)) + 1$$
# $$q = 2^{32}$$
# $$p = 2^5$$

# %%
print("inf-Norm of zw:", get_inf_norm_matrix(zw))
# Out:
# inf-Norm of zw: 2499

# %%
print("inf-Norm of xw:", get_inf_norm_matrix(xw))
# Out:
# inf-Norm of xw: 17106268391

# %%
p1 = 23835 * 1024 + 1
q = 1 << 32
p = 1 << 5

# %%
falcon = Falcon(256)

# %%
sk, vk = falcon.keygen()

# %%
ig = falcon.sign(sk, b'testing falcon sign')

# %%
falcon.verify(vk, b'testing falcon sign', ig)
# Out:
# True

# %% [markdown]
# ### Generating xtoken

# %%
xtoken = xw.__matmul__(zw)

# %%
def lwr(lst, q, p):
    """
    Apply LWR rounding from modulus q to modulus p.
    
    For each a in lst:
        a <- a mod q
        return round(p * a / q) mod p
    """
    result = []
    for a in lst:
        a_mod = a % q
        # print(a_mod)
        scaled = (a_mod * p) / q
        rounded = int(round(scaled)) % p
        # print(scaled, rounded)
        result.append(rounded)
        # return
    return result

# %%
a, b, c, d = lwr(xtoken.a, q, p1), lwr(xtoken.b, q, p1), lwr(xtoken.c, q, p1), lwr(xtoken.d, q, p1)
xtoken_r = PolyMatrix2x2(a, b, c, d)

# %%
print("inf-Norm of xtoken:", get_inf_norm_matrix(xtoken))
# Out:
# inf-Norm of xtoken: 51515738518552415401

# %%
rsign = falcon.raw_sign(sk, b'testing falcon sign') ## this gives a vector of 2 polynomials

# %%
temp_poly = PolyMatrix2x2(rsign[0], 256 * [0], rsign[1], 256 * [0])
print("inf_norm of signature: ", get_inf_norm_matrix(temp_poly))
# Out:
# inf_norm of signature:  951

# %%
xtag = xw.__matmul__(temp_poly)

# %% [markdown]
# ### Generating xtag

# %%
a, b, c, d = lwr(xtag.a, q, p), lwr(xtag.b, q, p), lwr(xtag.c, q, p), lwr(xtag.d, q, p)
xtag_r = PolyMatrix2x2(a, b, c, d)

# %% [markdown]
# ### Generating ytag

# %%
ytag = zw_inv.__matmul__(temp_poly)

# %%
a, b, c, d = lwr(ytag.a, p1, p1), lwr(ytag.b, p1, p1), lwr(ytag.c, p1, p1), lwr(ytag.d, p1, p1)
ytag_r = PolyMatrix2x2(a, b, c, d)
print("inf-Norm of ytag:", get_inf_norm_matrix(ytag_r))
# Out:
# inf-Norm of ytag: 48782511

# %% [markdown]
# ### Generating xtoken * ytag

# %%
hypoth = xtoken_r.__matmul__(ytag)

# %%
a, b, c, d = lwr(hypoth.a, p1, p), lwr(hypoth.b, p1, p), lwr(hypoth.c, p1, p), lwr(hypoth.d, p1, p)
hypoth_r = PolyMatrix2x2(a, b, c, d)

# %%
xtag_r
# Out:
# [ 10 + 8x + 30x^2 + 1x^3 + 13x^4 + 1x^5 + 26x^6 + 10x^7 + 4x^8 + 15x^9 + 9x^10 + 25x^11 + 15x^12 + 10x^13 + 2x^14 + 25x^15 + 8x^16 + 27x^17 + 25x^18 + 8x^19 + 4x^20 + 21x^21 + 16x^22 + 10x^23 + 3x^24 + 7x^25 + 2x^26 + 8x^27 + 10x^28 + 30x^29 + 2x^30 + 11x^31 + 20x^32 + 3x^33 + 23x^34 + 24x^35 + 7x^36 + 21x^37 + 1x^38 + 12x^39 + 11x^40 + 21x^41 + 27x^42 + 24x^43 + 31x^44 + 4x^45 + 21x^46 + 26x^47 + 12x^48 + 9x^49 + 11x^50 + 28x^51 + 16x^52 + 5x^54 + 12x^55 + 23x^56 + 21x^57 + 15x^58 + 21x^59 + 7x^60 + 22x^61 + 11x^62 + 26x^63 + 26x^64 + 15x^65 + 15x^66 + 3x^67 + 21x^68 + 20x^69 + 12x^71 + 27x^72 + 18x^73 + 31x^74 + 21x^75 + 21x^76 + 21x^77 + 9x^78 + 30x^79 + 1x^80 + 26x^81 + 16x^82 + 14x^83 + 8x^84 + 9x^85 + 5x^86 + 20x^87 + 3x^88 + 20x^89 + 23x^90 + 25x^91 + 7x^92 + 2x^93 + 17x^94 + 18x^95 + 4x^96 + 5x^97 + 2x^98 + 2x^99 + 16x^100 + 26x^101 + 18x^102 + 6x^103 + 1x^104 + 5x^105 + 4x^106 + 22x^107 + 5x^108 + 27x^109 + 18x^110 + 28x^111 + 28x^112 + 31x^113 + 2x^114 + 15x^115 + 30x^116 + 28x^118 + 7x^119 + 16x^120 + 30x^121 + 21x^122 + 30x^123 + 4x^124 + 29x^125 + 27x^126 + 10x^127 + 1x^128 + 28x^129 + 13x^130 + 4x^131 + 29x^132 + 19x^133 + 13x^134 + 15x^135 + 20x^136 + 8x^137 + 21x^138 + 23x^139 + 8x^140 + 9x^141 + 11x^142 + 28x^143 + 25x^144 + 23x^145 + 4x^146 + 22x^147 + 8x^148 + 30x^149 + 13x^150 + 28x^151 + 2x^152 + 12x^153 + 27x^154 + 3x^155